# %% [markdown]
# <a href="https://colab.research.google.com/github/gautampatil-groot/Playstore-App-Review-Analysis/blob/main/Play_Store_App_Review_Analysis_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    -  Play Store App Review Analysis EDA
# ##### **Contribution**    -  Individual
# ##### **Team Member 1 -** Gautam Patil

# %% [markdown]
# ## **Project Summary -**

# %% [markdown]
# ## **Playstore App Review Analysis Summary**
#
# Google Play, also known as the Google Play Store and formerly the Android Market, is a digital distribution service operated and developed by Google.
# It allows users to browse and download applications developed with the Android software development kit (SDK) and published through Google. Google Play has also served as a digital media store, offering games, music, books, movies, and television programs.
# Top apps with most installs and positive reviews

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The Play Store offers a tonne of potential, but in order for developers to build a successful business, they must research the market for the critical elements that influence app success and engagement. The insights can be obtained by applying Data Wrangling tools, and with the aid of those Key Factors, the developers would have a comprehensive understanding of the industry.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective of the Playstore App Review Analysis is to gain insights into the app market and identify trends and patterns that can be used to improve business strategies. The analysis aims to answer key questions related to app categories, ratings, installs, pricing, size, and user reviews, in order to help businesses make informed decisions about app development and marketing.
#
# By analyzing the data and answering the above 11 questions, businesses can gain a better understanding of the app market and user preferences. This can help businesses identify potential areas for growth and improvement, as well as develop targeted marketing and pricing strategies to increase user engagement and revenue. Ultimately, the goal of the Playstore App Review Analysis is to help businesses stay competitive in the fast-paced and ever-changing app market.

# %% [markdown]
# # ***Understand your data***

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
app_df = pd.read_csv('/content/drive/MyDrive/Datasets/Play Store Data.csv')
rev_df = pd.read_csv('/content/drive/MyDrive/Datasets/User Reviews.csv')

# %%
# Creating the copy of Original Dastaset
app = app_df.copy()
rev = rev_df.copy()

# %%
# Displaying the first 5 Rows
app.head().T
# Out:
#                                                              0  \
# App             Photo Editor & Candy Camera & Grid & ScrapBook
# Category                                        ART_AND_DESIGN
# Rating                                                     4.1
# Reviews                                                    159
# Size                                                       19M
# Installs                                               10,000+
# Type                                                      Free
# Price                                                        0
# Content Rating                                        Everyone
# Genres                                            Art & Design
# Last Updated                                   January 7, 2018
# Current Ver                                              1.0.0
# Android Ver                                       4.0.3 and up
#
#                                         1  \
# ...

# %%
# Displaying the last 5 Rows
app.tail().T
# Out:
#                            10836                             10837  \
# App             Sya9a Maroc - FR  Fr. Mike Schmitz Audio Teachings
# Category                  FAMILY                            FAMILY
# Rating                       4.5                               5.0
# Reviews                       38                                 4
# Size                         53M                              3.6M
# Installs                  5,000+                              100+
# Type                        Free                              Free
# Price                          0                                 0
# Content Rating          Everyone                          Everyone
# Genres                 Education                         Education
# Last Updated       July 25, 2017                      July 6, 2018
# Current Ver                 1.48                               1.0
# Android Ver           4.1 and up                        4.1 and up
#
# ...

# %%
# Dataset Rows and Columns
app.shape
# Out:
# (10841, 13)

# %%
# Dataset Information
app.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# Missing Values count
app.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Missing Values Heatmap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
fig, ax = plt.subplots(figsize=(10, 8))
sns.set(font_scale=1.2)
sns.heatmap(app.isnull(), cmap=cmap, cbar=False, ax=ax)
ax.set_title('Missing Values in App DataFrame')
plt.xticks(rotation = 75)
ax.set_xlabel('Column')
ax.set_ylabel('Row')
plt.show()

# %%
# Dataset Columns
app.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# App Statistics Overview
app.describe(include = 'all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
#Unique Value Counts
for i in app.columns.tolist():
  print("The Uniques values are",i, ":" , app[i].nunique())
# Out:
# The Uniques values are App : 9660
# The Uniques values are Category : 34
# The Uniques values are Rating : 40
# The Uniques values are Reviews : 6002
# The Uniques values are Size : 462
# The Uniques values are Installs : 22
# The Uniques values are Type : 3
# The Uniques values are Price : 93
# The Uniques values are Content Rating : 6
# The Uniques values are Genres : 120
# The Uniques values are Last Updated : 1378
# The Uniques values are Current Ver : 2832
# The Uniques values are Android Ver : 33

# %%
# Data Cleaning
app.dropna(how = 'any',inplace  =True)

# %%
# Duplicate Apps Count
print("The Number of unique apps" , len(app['App'].unique()))
print("Number of total apps", app.shape[0])
print("The number of duplicate apps", len(app['App']) - len(app['App'].unique()))
# Out:
# The Number of unique apps 8190
# Number of total apps 9360
# The number of duplicate apps 1170

# %%
#Remove Duplicate Apps
app.drop_duplicates(subset = 'App', keep = 'first', inplace = True)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset is a Play Store app review analysis dataset that consists of the following columns:
#
#
#
# * App
# * Category
# * Rating
# * Reviews
# * Size
# * Installs
# * Type
# * Price
# * Content Rating
# * Genres
# * Last Updated
# * Current Ver
# * Android Ver
#
# This data can give us insights into various aspects of the apps available on the Play Store, including the popularity of certain apps, the ratings and reviews received by the apps, and the different characteristics of the apps such as size, type, price, content rating, etc. This information can be useful for app developers, app marketers, and anyone else who is interested in understanding the Play Store app ecosystem.

# %% [markdown]
# ### Variables Description

# %% [markdown]
# App: The name of the mobile application.
# Category: The category to which the app belongs (e.g., Business, Communication, Entertainment, etc.).
# Rating: The average user rating of the app (ranges from 1 to 5).
# Reviews: The number of user reviews for the app.
# Size: The size of the app in kilobytes (kB).
# Installs: The approximate number of app installs (e.g., 1,000,000+).
# Type: Whether the app is free or paid.
# Price: The price of the app if it is a paid app.
# Content Rating: The target audience age group for the app (e.g., Everyone, Teen, Mature 17+, etc.).
# Genres: The genre(s) to which the app belongs.
# Last Updated: The date when the app was last updated.
# Current Ver: The current version of the app.
# Android Ver: The minimum required Android version to run the app.

# %% [markdown]
# ---

# %% [markdown]
# ## **Data Cleaning**

# %%
app_grouped = app.groupby(['Category', 'Type']).count().reset_index()

# %%
# Extract top 22 categories
category_ = app['Category'].value_counts().reset_index().head(22)
category_.columns = ['Category_Name', 'Count']

# %%
# Extract non-null app ratings
rating_df = app[~app['Rating'].isna()]['Rating']

# %%
# Data Cleaning and Type Conversion of 'Installs'.
app['Installs'] = app['Installs'].str.replace("+","")
app['Installs'] = app['Installs'].str.replace(",","")
app['Installs'] = app['Installs'].astype(int)
# Out:
# <ipython-input-20-154a17f7690e>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   app['Installs'] = app['Installs'].str.replace("+","")

# %%
#Top 20 apps with most reviews
app['Reviews'] = app['Reviews'].astype(int)
print("Top 20 apps with most reviews: \n",app[app['Reviews'] > 10000000].sort_values(by = 'Reviews').head(20)['App'])
# Out:
# Top 20 apps with most reviews:
#  3975                                              Hay Day
# 1893                                              Yes day
# 1694             Minion Rush: Despicable Me Official Game
# 1764                                           Pokémon GO
# 391                         Skype - free IM & video calls
# 1662                                                  Pou
# 403                           LINE: Free Calls & Messages
# 2808                                        Google Photos
# 1932                                       Shadow Fight 2
# 342                                       Viber Messenger
# 3739                                              Twitter
# 3239    Cache Cleaner-DU Speed Booster (booster & clea...
# 406                           BBM - Free Calls & Messages
# 8896    DU Battery Saver - Battery Charger & Battery Life
# 1675                                          8 Ball Pool
# 1722                                       My Talking Tom
# ...

# %%
# Converts price column to float type.
app['Price'] = app['Price'].apply(lambda x: x.replace("$",""))
app['Price'] = app['Price'].astype(float)

# %%
app['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '5.5M', '17M', '39M', '31M',
#        '4.2M', '23M', '6.0M', '6.1M', '4.6M', '9.2M', '5.2M', '11M',
#        '24M', 'Varies with device', '9.4M', '15M', '10M', '1.2M', '26M',
#        '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M', '5.7M',
#        '8.6M', '2.4M', '27M', '2.7M', '2.5M', '7.0M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '22M', '6.4M', '3.2M', '8.2M', '4.9M', '9.5M', '5.0M',
#        '5.9M', '13M', '73M', '6.8M', '3.5M', '4.0M', '2.3M', '2.1M',
#        '42M', '9.1M', '55M', '23k', '7.3M', '6.5M', '1.5M', '7.5M', '51M',
#        '41M', '48M', '8.5M', '46M', '8.3M', '4.3M', '4.7M', '3.3M', '40M',
#        '7.8M', '8.8M', '6.6M', '5.1M', '61M', '66M', '79k', '8.4M',
# ...

# %%
# Modifying the 'Size' Column in a DataFrame
app['Size'] = app['Size'].str.replace("k","")
app['Size'] = app['Size'].str.replace("M","*1000")
app['Size'] = app['Size'].str.replace("Varies with device","-1")
app['Size'] = app['Size'].apply(lambda x: eval(x))
app['Size'] = app['Size'].replace(-1,np.nan)
app['Size'].fillna(np.mean(app['Size']),inplace = True)
app['Size']
# Out:
# 0        19000.000000
# 1        14000.000000
# 2         8700.000000
# 3        25000.000000
# 4         2800.000000
#              ...
# 10834     2600.000000
# 10836    53000.000000
# 10837     3600.000000
# 10839    21767.533044
# 10840    19000.000000
# Name: Size, Length: 8190, dtype: float64

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# ## **1. Which category contains the most different sorts of apps?**

# %%
# Creates a bar plot with color-coded categories.
plt.figure(figsize=(10, 8))
sns.barplot(x='Category', y='App', hue='Type', data=app_grouped, palette=['#FFA07A', '#6495ED'])

# Sets plot title, xticks, and yticks.
plt.xlabel('Category')
plt.ylabel('Number of Apps')
plt.title('Number of Free and Paid Apps per Category')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### **1. Why did you pick the specific chart?**
#
# I picked a bar chart because it is an effective way to represent the count  of elements in each category. The bar chart clearly shows the count of apps in each category and helps to visualize the data in a simple and straightforward manner.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**
#
# The insight that we can gather from the chart is that some categories have a larger number of apps compared to others. For example, the "FAMILY" and "GAME" categories have the largest number of apps, while categories such as "EVENTS" and "BEAUTY" have relatively fewer apps.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
#
# The insights from the chart can be useful for business as they provide a clear understanding of the market share for different categories. For example, if a business is interested in developing an app for the "FAMILY" category, they would know that there are already a significant number of apps in this category and that the competition is likely to be high. On the other hand, if a business is interested in developing an app for a category with fewer apps, they might have more opportunities to differentiate their app and capture market share.

# %% [markdown]
# ### **4. Are there any insights that lead to negative growth? Justify with specific reason.**
#
# No, the insights from the chart do not necessarily lead to negative growth.  However, it is possible that businesses might face challenges in a highly competitive category with many apps. But this can be overcome with good marketing and a well-designed app that stands out from the competition.

# %% [markdown]
# ## **2. What is the Density of Rating?**

# %%
# Set plot size and style
sns.set(rc={'figure.figsize':(10, 8)})
sns.set_style('whitegrid')

# Create density plot of ratings
g = sns.displot(rating_df, kind = 'hist', kde=True, aspect = 2)

#Labels
g.set_axis_labels("Rating", "Density")

# Display the plot
plt.show()

# %% [markdown]
# ### **1. Why did you pick the specific chart?**
# The specific chart was picked to visualize the density of app ratings on the Google Play Store.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**
# The insight found from the chart is that most of the apps have a rating of 4 to 5 stars, with a slight concentration towards the higher end. There is a sharp drop in the density of ratings beyond 4.5 stars, which suggests that very few apps receive a perfect rating.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
# Yes, the insights gained from the chart can help in creating a positive business impact as they provide an understanding of the general rating distribution of apps on the Google Play Store. This information can be useful for app developers in improving their app quality to get better ratings and attract more users.

# %% [markdown]
# ### **4. Are there any insights that lead to negative growth? Justify with specific reason.**
# No, there are no insights that lead to negative growth as the chart only provides a visualization of the app rating distribution and does not provide information about the growth of the app.

# %% [markdown]
# ## **3. What are the top 6 categories and its rating distribution ?**

# %%
# Set plot size and style
sns.set(rc={'figure.figsize':(18, 12)})
sns.set_style('whitegrid')

# Define list of categories for subplots
categories = ['GAME', 'FAMILY', 'TOOLS', 'FINANCE', 'PRODUCTIVITY', 'LIFESTYLE']

# Create 2x3 grid of subplots
fig, ax = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle("Distribution of Ratings across Categories", fontsize=30, y=1.05)

# Create and customize density plot for each category
for i, category in enumerate(categories):
    row = i // 3
    col = i % 3
    sns.kdeplot(app[app['Category'] == category]['Rating'], shade=True, ax=ax[row, col])
    ax[row, col].set_title(category, fontsize=20)
    ax[row, col].set_xlabel("Rating", fontsize=15)
    ax[row, col].set_ylabel("Density", fontsize=15)

# Adjust spacing between subplots and display the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-27-35638a440665>:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(app[app['Category'] == category]['Rating'], shade=True, ax=ax[row, col])
# <ipython-input-27-35638a440665>:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(app[app['Category'] == category]['Rating'], shade=True, ax=ax[row, col])
# <ipython-input-27-35638a440665>:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(app[app['Category'] == category]['Rating'], shade=True, ax=ax[row, col])
# <ipython-input-27-35638a440665>:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...

# %% [markdown]
# ### **1. Why did you pick the specific chart?**
# The specific chart was picked to visualize the distribution of ratings for the top 6 app categories in the Google Play Store.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**
# The insights found from the chart include the distribution of ratings for each of the top 6 app categories in the Google Play Store. It shows the spread of the ratings and identifies the categories with higher density of higher ratings.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
# The insights can help app developers and businesses to understand the trends and preferences of users in different categories, and cater to the users' demands by improving the app quality. This could lead to a positive impact on the app ratings and overall business performance.

# %% [markdown]
# ### **4. Are there any insights that lead to negative growth? Justify with specific reason.**
# The insights from this chart alone do not lead to negative growth. However, if the app developers and businesses find that their app has a lower rating compared to other apps in the same category, it could indicate areas for improvement and lead to negative growth if not addressed properly.

# %% [markdown]
# ## **4. What is a combined visualization of content rating distribution ?**

# %%
# Content Rating Categorization and Consolidation.
content_rating = app['Content Rating'].value_counts()
threshold = 0.03 # set threshold for small percentage values
small_categories = content_rating[content_rating/sum(content_rating) < threshold].index
content_rating['Other'] = content_rating[small_categories].sum()
content_rating.drop(small_categories, inplace=True)

# Customized Color Palette Visualization.
plt.figure(figsize = (8,8))
sns.set_palette("Set2")

# Content Rating Distribution Pie Chart.
content_rating.plot(kind = 'pie', fontsize = 12, explode = (0.13, 0.13, 0.13, 0.13, 0.13), autopct = '%1.2f%%', pctdistance=0.8, labeldistance = 1.1,)

# Content Rating Legend and Title.
plt.legend(title = "Content Rating", bbox_to_anchor=(0.9, 0, 0.5, 1))
plt.title("Content Rating Distribution", fontsize=20)
plt.show()

# %% [markdown]
# ### **1. Why did you pick the specific chart?**
# I picked a pie chart to display the distribution of Content Rating categories in the Play Store app data.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**
# The pie chart shows that the majority of the apps (around 44%) have a "Everyone" Content Rating, followed by "Teen" at around 21%. The rest of the Content Rating categories have much lower proportions.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
# Yes, this information can be useful for app developers and marketers to understand the target audience for their app and to ensure that the app's content aligns with the appropriate Content Rating category.

# %% [markdown]
# ### **4. Are there any insights that lead to negative growth? Justify with specific reason.**
# No, this pie chart does not indicate any negative growth. It only provides information about the distribution of Content Rating categories in the Play Store app data, which is a neutral piece of information.

# %% [markdown]
# ---

# %% [markdown]
# ## **5. What is the relationship between the number of installs and the type of app ?**

# %%
# Box Plot Comparison of Installs by App Type.
plt.figure(figsize=(8, 6))
sns.boxplot(x='Type', y='Installs', data=app, flierprops = {"marker" : "x"}, medianprops = {'color' : 'red'})

# Labels and Title for Installs vs Type Box Plot.
plt.xlabel("Type", fontsize=15)
plt.ylabel("Installs", fontsize=15)
plt.yscale('log')
plt.title("Installs vs Type", fontsize=20)
plt.show()

# %% [markdown]
# ### **1. Why did you pick the specific chart?**
# I picked the Box Plot Comparison of Installs by App Type chart because it effectively compares the distribution of app installs between the two app types, Free and Paid, and allows for easy identification of differences in the medians, quartiles, and outliers.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**
# From the chart, we can see that the median number of installs for Free apps is significantly higher than for Paid apps. Additionally, Free apps have a wider distribution of installs with a larger number of outliers.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
# The insights gained from the chart can be helpful in making business decisions, such as determining which app type to focus on for growth, how to price and market each app type, and identifying potential areas for improvement in app features or customer experience.

# %% [markdown]
# ---

# %% [markdown]
# ## **6. What is the relationship between the ratings and the number of installs ?**

# %%
# Violin Plot of Rating vs Installs.
plt.figure(figsize=(25,9))
sns.violinplot(x = app['Installs'], y = app['Rating'])
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ### **1. Why did you pick the specific chart?**
# I picked the violin plot to show the distribution of app ratings for different levels of installs.
#
# ### **2. What is/are the insight(s) found from the chart?**
# The chart shows that apps with higher number of installs tend to have higher ratings. It also shows that the most common rating is around 4.3-4.5.
#
# ### **3. Will the gained insights help creating a positive business impact?**
# Yes, understanding the relationship between app installs and ratings can help businesses in developing strategies to increase their app installs and improve their ratings.

# %% [markdown]
# ## **7. How does the joint distribution of ratings and reviews vary between apps with relatively high and relatively low number of reviews? ?**

# %%
# Joint plot of Rating vs Reviews for apps with more than 100,000 reviews.
sns.jointplot(x='Reviews',y='Rating',data =app[app['Reviews']>100000],color='darkgreen')
plt.title("More than 1M")
plt.show()

# Joint plot of Rating vs Reviews for apps with less than 100,000 reviews.
sns.jointplot(x='Reviews',y='Rating',data =app[app['Reviews']<100000],color ='darkorange')
plt.title("Below than 1M")
plt.show()

# %% [markdown]
# ### **1. Why did you pick the specific chart?**
#
# I picked two joint plots to explore the relationship between Rating and Reviews for apps with more than and less than 100,000 reviews, respectively.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**
#
# The joint plots show that for both groups of apps, there is a positive correlation between Reviews and Rating.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
#
# Yes, understanding the relationship between Reviews and Rating can help businesses identify factors that influence app success and make informed decisions about app development and marketing strategies.

# %% [markdown]
# ## **8. What is the distribution of different types of apps represented in the dataset ?**

# %%
# Distribution of App Types in a Pie Chart
a= app['Type'].value_counts().reset_index()
plt.pie(x = a['Type'], labels = a['index'], autopct = '%1.1f%%', shadow = True, startangle = 90, explode = (0.25, 0))
plt.show()

# %% [markdown]
# ##### **From above Pieplot we can conclude - Playstore have 7.4% paid apps**

# %% [markdown]
# ## **9. What is the price range based on rating ?**

# %%
# Filter out apps with price greater than 200
app_filtered = app[app['Price'] < 200]

# Plot rating vs. price for paid apps
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Price', y='Rating', data=app_filtered[app_filtered['Type'] == 'Paid'], color='#6495ED')
plt.xlabel('Price')
plt.ylabel('Rating')
plt.title('Rating vs. Price for Paid Apps')
plt.show()

# %% [markdown]
# ### **1. Why did you pick the specific chart?**
#
# I chose a scatterplot because it effectively displays the relationship between two continuous variables, price and rating, for the filtered dataset of paid apps.
#
# ### **2. What is/are the insight(s) found from the chart?**
#
# The scatterplot suggests that there is a weak positive correlation between price and rating for paid apps in the filtered dataset. This means that, on average, paid apps with higher prices tend to have slightly higher ratings than paid apps with lower prices.
#
# ### **3. Will the gained insights help creating a positive business impact?**
#
# The gained insight can help create a positive business impact by potentially increasing customer satisfaction and allowing app developers to experiment with pricing strategies for their paid apps.

# %% [markdown]
# ## **10. What is the distribution of app sizes in the dataset ?**

# %%
# Plot distribution of app sizes.
plt.figure(figsize = (18,9))
sns.displot(app['Size'], height = 5, aspect = 3)
plt.xlabel("Size in kbs")

# Adjusting x-tick marks for size distribution.
plt.xticks(list(range(0, int(max(app['Size'])), 5000)))
plt.show()

# %% [markdown]
# ### **1. Why did you pick the specific chart?**
# I picked it because it visualizes the distribution of app sizes in kilobytes, which can give insights into the typical size range of apps in the dataset.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**
# The chart shows that the majority of apps have sizes below 30,000 kilobytes, with a long tail of larger sizes. This can be helpful for developers to understand the typical size range of apps and make decisions about optimizing their app size for better user experience and performance.
#
# ### **3. Will the gained insights help creating a positive business impact?**
# The gained insights could help creating a positive business impact by enabling developers to optimize their app size and potentially improve user satisfaction, leading to higher user engagement, retention, and revenue.

# %% [markdown]
# ---

# %% [markdown]
# ## **11. What is the relationship between sentiment polarity and subjectivity in the reviews**

# %%
# Filter out rows with missing values in the Sentiment_Polarity and Sentiment_Subjectivity columns
rev = rev.dropna(subset=['Sentiment_Polarity', 'Sentiment_Subjectivity'])

# Create the scatter plot
plt.scatter(rev['Sentiment_Polarity'], rev['Sentiment_Subjectivity'], alpha=0.5)

# Set the axis labels and title
plt.xlabel('Sentiment Polarity')
plt.ylabel('Sentiment Subjectivity')
plt.title('Sentiment Analysis Scatter Plot')

# Show the plot
plt.show()

# %% [markdown]
# ### **1. Why did you pick the specific chart?**
# The scatter plot effectively displays the relationship between sentiment polarity and subjectivity in app reviews, allowing for easy identification of patterns or trends.
#
# ### **2. What is/are the insights found from the chart?**
# The scatter plot shows that there is a moderate positive correlation between sentiment polarity and subjectivity in app reviews, indicating that more subjective reviews tend to be more positive. ##indicating that app reviews tend to be more objective when they are negative.
#
# ### **3. Will the gained insights help creating a positive business impact?**
# The insights can help app developers and business owners understand the nature of customer sentiment towards their app, potentially leading to improvements in the app and increased customer satisfaction.

# %%
sns.kdeplot(rev[rev['Sentiment']=='Positive']['Sentiment_Polarity'], fill=True, label='Positive')
sns.kdeplot(rev[rev['Sentiment']=='Neutral']['Sentiment_Polarity'], fill=True, label='Neutral', warn_singular=False)
sns.kdeplot(rev[rev['Sentiment']=='Negative']['Sentiment_Polarity'], fill=True, label='Negative')
plt.title('Sentiment Polarity by Sentiment')
plt.xlabel('Sentiment Polarity')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ## **Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# #### 1. The client should focus on the category that contains the most different sorts of apps as it has the potential to attract a larger audience.
#
# #### 2. The density of ratings is mostly concentrated between 3.5 to 4.5. The client can focus on improving the overall ratings of the app to fall within this range.
#
# #### 3.The client can focus on the top 6 categories and their rating distribution to analyze the potential for growth and improvement.
#
# #### 4. The client can use a combined visualization of content rating distribution to understand the distribution of ratings based on content and genre.
#
# #### 5. The client should analyze the relationship between the number of installs and the type of app to understand user preferences and tailor their marketing strategy accordingly.
#
# #### 6. The client can analyze the relationship between ratings and the number of installs to understand the correlation between user ratings and app installs.
#
# #### 7. By comparing the joint distribution of ratings and reviews between apps with relatively high and relatively low number of reviews, the client can identify patterns and improve the overall rating and review count.
#
# #### 8. The distribution of different types of apps represented in the dataset should be analyzed to identify the types of apps that are popular among users.
#
# #### 9. The client can analyze the price range based on rating to understand the correlation between pricing and user ratings.
#
# #### 10. The distribution of app sizes in the dataset should be analyzed to understand user preferences for app sizes.
#
# #### 11. The client can analyze the relationship between sentiment polarity and subjectivity in the reviews to improve the overall sentiment and feedback of the users.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Family category contains the most different sorts of apps.
# The density of rating lies between 3.5 to 4.7.
# The top 6 categories are Game, Family, Tools, Medical, Business, and Productivity. The rating distribution for each of these categories is different.
# The combined visualization of content rating distribution shows that the majority of the apps are rated for Everyone.
# The type of app (Free or Paid) does not seem to have a significant impact on the number of installs.
# There is a weak positive correlation between ratings and installs.
# The joint distribution of ratings and reviews varies between apps with relatively high and relatively low numbers of reviews.
# The majority of apps in the dataset are Free.
# There is no clear relationship between the price of an app and its rating.
# The distribution of app sizes is right-skewed, with most apps being small in size.
# There is a weak positive correlation between sentiment polarity and subjectivity in the reviews.
#
# In conclusion, we have analyzed the Playstore App Review dataset using various visualizations and statistical techniques. From the analysis, we can infer that the Family category contains the most different sorts of apps. The density of rating lies between 3.5 to 4.7, which indicates that most apps are rated above average. The top 6 categories are Game, Family, Tools, Medical, Business, and Productivity, and the rating distribution for each of these categories is different.
#
# We found that the type of app (Free or Paid) does not seem to have a significant impact on the number of installs. There is a weak positive correlation between ratings and installs, and the joint distribution of ratings and reviews varies between apps with relatively high and relatively low numbers of reviews. Additionally, we found that the majority of apps in the dataset are free, and there is no clear relationship between the price of an app and its rating.
#
# Furthermore, the distribution of app sizes is right-skewed, with most apps being small in size. Lastly, we found a weak positive correlation between sentiment polarity and subjectivity in the reviews. Based on these insights, we suggest that the client should focus on developing apps in the Family, Game, Tools, Medical, Business, and Productivity categories, which have high potential for success. They should also consider offering free apps, as the majority of the apps in the dataset are free, and there is no clear relationship between the price of an app and its rating. Additionally, they should aim to develop smaller-sized apps, as most apps are small in size. Finally, they should monitor the sentiment polarity and subjectivity in the reviews to ensure that their apps are meeting the needs of their users.
